# %% [markdown]
# # Solution Exercise 4.2

# %%
import plotly.express as px
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('gapminder.csv')
df.head()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138       AFG
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106       AFG
#
#    iso_num
# 0        4
# 1        4
# 2        4
# 3        4
# 4        4

# %%
df['continent'].unique()
# Out:
# <StringArray>
# ['Asia', 'Europe', 'Africa', 'Americas', 'Oceania']
# Length: 5, dtype: str

# %%
# a) Make a Geographical bubble plot (Scatter Plot) representing the population in 1952
year=1952
fig = px.scatter_geo(df[df['year']==year], locations="iso_alpha", color="continent",
                     hover_name="country", size="pop",
                     projection="natural earth",
                     width=1000, height=600)
fig.show()

# %%
# b) Add the names of the continents onto the map, e.g. in the place of the largest country in each continent, or in the middle of each continent.

# Identify the indices of maximum population for each continent
max_pop_indices = df[df['year']==year].groupby(['continent'])['pop'].idxmax()

# Create a new column 'largest_pop_continent' and initialize it with an empty string
df['largest_pop_in_continent'] = ""

# Assign the corresponding 'continent' values to the 'largest_pop_continent' column
df.loc[max_pop_indices, 'largest_pop_in_continent'] = df.loc[max_pop_indices, 'continent']

# Plot 
fig = px.scatter_geo(df[df['year']==year], locations="iso_alpha", color="continent",
                     hover_name="country", size="pop",
                     projection="natural earth",
                     text='largest_pop_in_continent',
                     width=1000, height=600)
fig.show()

# %%
# c) Plot a choropleth map representing life expectancy in the world in 2007
fig = px.choropleth(df[df['year']==2007], locations="iso_alpha",
                    color="lifeExp", 
                    projection="natural earth",
                    hover_name="country")
fig.show()

# %%
# d) Make an animation over the years instead of a fixed map of 2007
fig = px.choropleth(df, locations="iso_alpha",
                    color="lifeExp", 
                    animation_frame='year',
                    projection="natural earth",
                    range_color=(min(df['lifeExp']), max(df['lifeExp'])),
                    hover_name="country")
fig.show()
# Comment: Important to fix the range_color to have a comparable evolution

# %%
# e) Find a geojson (or shapefile or else) of your choice online, import it and plot it with the data of your choice (found online or made up).

# See ex4_2e.ipynb
