# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %% [markdown]
# ### a)

# %%
df = pd.read_csv("iris.csv")

# %%
sns.pairplot(df, hue="variety", diag_kind="kde")

# %% [markdown]
# ### b)

# %%
pd.plotting.parallel_coordinates(df, class_column="variety", color=["black", "red", "blue"])
# Out:
# <Axes: >

# %% [markdown]
# ### c)

# %%
# sns.heatmap(df["petal.length", "petal.width", "sepal.length", "sepal.width"])
