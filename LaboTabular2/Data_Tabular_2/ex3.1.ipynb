# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv("iris.csv")

# %% [markdown]
# ### a)

# %%
sepal_length_mean = df["sepal.length"].mean()
s_df = df.loc[df["sepal.length"] >= sepal_length_mean]
sns.barplot(s_df)
# Out:
# <Axes: >

# %% [markdown]
# ### b)
