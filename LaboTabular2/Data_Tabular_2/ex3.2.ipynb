# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %% [markdown]
# ### a)

# %%
df = pd.read_csv("medals_long.csv")

# %%
new_df = df.pivot(index="nation", columns="medal", values="count")
new_df = new_df.reindex(["gold", "silver", "bronze"], axis=1)
display(new_df)
# Out:
# medal        gold  silver  bronze
# nation
# Canada          9      12      12
# China          10      15       8
# South Korea    24      13      11

# %% [markdown]
# ### b)

# %%
new_df.plot(kind="bar", stacked=True, color=["gold", "silver", "brown"])
# Out:
# <Axes: xlabel='nation'>
